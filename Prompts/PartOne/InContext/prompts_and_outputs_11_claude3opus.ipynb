# %% [markdown]
# data\main_samples_1.csv
#
# Total NSF organisation (manually filtered): 16
#
# Organisation	NSF
# NSF Grant from the US National Science Foundation	1
# NSF-ELT program	1
# NSF Aeronomy Program	1
# National Science Foundation NRT	1
# National Science Foundation LTER program	1
# National Science Foundation ADVANCE grant	1
# NSF MWN	1
# National High Magnetic Field Laboratory through the NSF 1
# National Science Foundation and Environmental Protection Agency program Networks for Sustainable Material Synthesis and Design	1
# NSF at Northwestern University	1
# U.S.National Science Foundation (NSF)	1
# National Science Foundation through the Nanoscale Science and Engineering Center	1
# NSF/SHINE grant	1
# NSF CCR	1
# National Institutes of Health from the National Science Foundation	1
# National Science Foundation though PENN MRSEC	1

# %%
import pandas as pd

# Creating data dictionary
data = {
    "Organisation": [
        "NSF Grant from the US National Science Foundation",
        "NSF-ELT program",
        "NSF Aeronomy Program",
        "National Science Foundation NRT",
        "National Science Foundation LTER program",
        "National Science Foundation ADVANCE grant",
        "NSF MWN",
        "National High Magnetic Field Laboratory through the NSF",
        "National Science Foundation and Environmental Protection Agency program Networks for Sustainable Material Synthesis and Design",
        "NSF at Northwestern University",
        "U.S.National Science Foundation (NSF)",
        "National Science Foundation through the Nanoscale Science and Engineering Center",
        "NSF/SHINE grant",
        "NSF CCR",
        "National Institutes of Health from the National Science Foundation",
        "National Science Foundation though PENN MRSEC"
    ],
    "NSF": [1] * 16  # Repeating '1' for each entry, indicating affiliation
}

# Converting dictionary to DataFrame
df_main = pd.DataFrame(data)
df_main
# Out:
#                                          Organisation  NSF
# 0   NSF Grant from the US National Science Foundation    1
# 1                                     NSF-ELT program    1
# 2                                NSF Aeronomy Program    1
# 3                     National Science Foundation NRT    1
# 4            National Science Foundation LTER program    1
# 5           National Science Foundation ADVANCE grant    1
# 6                                             NSF MWN    1
# 7   National High Magnetic Field Laboratory throug...    1
# 8   National Science Foundation and Environmental ...    1
# 9                      NSF at Northwestern University    1
# 10              U.S.National Science Foundation (NSF)    1
# 11  National Science Foundation through the Nanosc...    1
# 12                                    NSF/SHINE grant    1
# 13                                            NSF CCR    1
# 14  National Institutes of Health from the Nationa...    1
# ...

# %% [markdown]
# ## Claude 3 opus

# %% [markdown]
# Data: data\samples_1\organisation_sample_1.csv
#
# Prompt:
#
# Context: A dataset contains a column named 'Organisation' which contains the organisation names of different funding organisations.
#
# Task: Your task is to display the organisation names that are affiliated to or a part of national science foundation (nsf). You can do this by checking if an organisation name has the complete string of 'national science foundation' or 'nsf' in it. Ignore the case specific string matching.
#
# Data to filter from:
# NSF Grant from the US National Science Foundation
# "Institute for Cellular and Molecular Biology, the University of Texas at Austin"
# Luxembourg Research Funding Association FNR (Fonds National de la Recherche)
# NSF-ELT program
# NSF Aeronomy Program
# Army Materiel Command
# Centers for Disease Control and Prevention (CDC) through the Association of American Medical Colleges (AAMC)
# National Science Foundation NRT
# UAB Health Services Foundation General Endowment Fund
# Chinese Major State Basic Development Program
# Spanish Guardia Civil
# FCT Combustion Pty. Ltd.
# "Fundacao Araucaria, Parana"
# Synthesis FP7-the European Union-funded Integrated Activities
# "11th Batch of Jiangsu ""Six Level Talents Peak"" Project"
# Province of Alberta
# "National Science and Engineering Research Council, Canada"
# "National Research Foundation of Korea (NRF) (MSIP, Ministry of Science, ICP and Future Planning)"
# Institutos do Milenio/CNPq/MCT
# Xinmiao Talent Project in Zhejiang Province
# National Science Foundation LTER program
# National Science Foundation ADVANCE grant
# NSF MWN
# Division of Engineering Education and Centers
# Health South-East Norway
#
# Output format: Display a list of the matched organization names followed by the reason for their selection in a json format with the organisation name as key and reason as value.
#
# Sample Input:
# NSF-GFRP
# ACTS national research program from the Netherlands
# Portuguese National Funds (FCT-Fundacao para a Ciencia e a Tecnologia)
# US National Institute of General Medicine
# NSF QIS
# FIST grant of DST
# National Science Foundation under IGERT award
#
# Sample Output:
# {
# 'NSF-GFRP': "contains the string 'nsf'",
# 'NSF QIS': "contains the string 'nsf'",
# 'National Science Foundation under IGERT award': "contains the string 'national science foundation'"
# }
#
# Additional note: You can also filter names of organizations without complete matches of strings 'nsf' or 'national science foundation' string, but make sure to provide a reason for displaying that match. There can be situations where none of the organisations match the criteria, then generate an empty json

# %%
sample_1 = {
"NSF Grant from the US National Science Foundation": "Contains both 'NSF' and 'National Science Foundation'",
"NSF-ELT program": "Contains 'NSF' in the name",
"NSF Aeronomy Program": "Contains 'NSF' in the name",
"National Science Foundation NRT": "Contains 'National Science Foundation' in the name",
"National Science Foundation LTER program": "Contains 'National Science Foundation' in the name",
"National Science Foundation ADVANCE grant": "Contains 'National Science Foundation' in the name",
"NSF MWN": "Contains 'NSF' in the name",
"Division of Engineering Education and Centers": "Part of the NSF based on the context and other entries"
}

# %% [markdown]
# Data: data\samples_1\organisation_sample_2.csv
#
# Prompt:
#
# Context: A dataset contains a column named 'Organisation' which contains the organisation names of different funding organisations.
#
# Task: Your task is to display the organisation names that are affiliated to or a part of national science foundation (nsf). You can do this by checking if an organisation name has the complete string of 'national science foundation' or 'nsf' in it. Ignore the case specific string matching.
#
# Data to filter from:
# Kellogg Health Scholars Program
# Fogarty International Center/NIAAA
# "Guangdong Provincial Science and Technology Planning Project of Guangdong Province, China"
# Atmospheric Radiation Measurement (ARM) Climate Research Facility
# "UK National Ecosystem Assessment Follow-On (Work Package 6: Shared, Plural and Cultural Values) - UK Department of the Environment, Food and Rural Affairs (Defra)"
# Canadian Research Chair Award
# Research Grant Council of Suleyman Demirel University
# Scientific Research Projects of Colleges and Universities of Hainan Province
# Government of India (GOI)
# Beckman Center
# "Centre National d'Etudes Spatiales, CNES"
# Citclops European project
# "Japanese Ministry of Education, Global Center of Excellence (GCOE) Program, ""International Research Center for Molecular Science in Tooth and Bone Diseases"""
# National Institute of Child Health and Development (NIH)
# Chung-Ang University Research Grants in 2018
# Plan Nacional I+D+I (Ministerio de Ciencia e Innovacion)
# "Plasma Diagnostics Using Fast Thomson Scattering through the National Research Foundation of Korea (NRF) - Ministry of Education, Science and Technology"
# project of national science and technology supporting plan
# "State Key Laboratory of Industrial Control Technology, Zhejiang University, China"
# Romanian Government through UEFISCDI
# Australian Government under its Climate Change Research Program
# SQHA
# Jiangsu Government Scholarship for Overseas Studies
# "Ministero dell' Istruzione, dell' Universita e della Ricerca (MIUR)"
# water project of CAS
#
# Output format: Display a list of the matched organization names followed by the reason for their selection in a json format with the organisation name as key and reason as value.
#
# Sample Input:
# NSF-GFRP
# ACTS national research program from the Netherlands
# Portuguese National Funds (FCT-Fundacao para a Ciencia e a Tecnologia)
# US National Institute of General Medicine
# NSF QIS
# FIST grant of DST
# National Science Foundation under IGERT award
#
# Sample Output:
# {
# 'NSF-GFRP': "contains the string 'nsf'",
# 'NSF QIS': "contains the string 'nsf'",
# 'National Science Foundation under IGERT award': "contains the string 'national science foundation'"
# }
#
# Additional note: You can also filter names of organizations without complete matches of strings 'nsf' or 'national science foundation' string, but make sure to provide a reason for displaying that match. There can be situations where none of the organisations match the criteria, then generate an empty json

# %%
sample_2 = {
"project of national science and technology supporting plan": "Contains 'national science' in the name, which might be related to the National Science Foundation"
}

# %% [markdown]
# Data: data\samples_1\organisation_sample_3.csv
#
# Prompt:
#
# Context: A dataset contains a column named 'Organisation' which contains the organisation names of different funding organisations.
#
# Task: Your task is to display the organisation names that are affiliated to or a part of national science foundation (nsf). You can do this by checking if an organisation name has the complete string of 'national science foundation' or 'nsf' in it. Ignore the case specific string matching.
#
# Data to filter from:
# "Department of Anesthesia, Critical Care, and Pain Medicine, Massachusetts General Hospital, Boston, Massachusetts"
# Higher Education Commission (HEC) Pakistan under National Research Program for Universities
# "Cultivation of Major Projects and Emerging, Interdisciplinary Fund, Sun Yat-Sen University"
# "Vorarlberger Aerztekammer (Dornbirn, Austria)"
# National High Magnetic Field Laboratory through the NSF
# National Science Foundation and Environmental Protection Agency program Networks for Sustainable Material Synthesis and Design
# "School of Ocean and Earth Science and Technology, University of Hawaii"
# NSF at Northwestern University
# Talent Recruitment Foundation of Huazhong University of Science and Technology
# Oxford BHF Centre of Research Excellence
# U.S.National Science Foundation (NSF)
# Whiteside Institute for Clinical Research
# Universidad Pedagogica y Tecnologica de Colombia (UPTC)
# INPAC and Shanghai Key Laboratory for Particle Physics and Cosmology
# "Reservoir Simulation Joint Industry Project, a consortium of operating and service companies for Petroleum and Geosystems Engineering at The University of Texas at Austin"
# "Ministerium fur Innovation, Wissenschaft und Forschung des Landes Nordrhein Westfalen"
# New Investigator Research Grant of Alzheimer's Association
# "Universidad Tecnica Federico Santa Maria, Chile"
# US Dept. of Education
# Embassy of France in Malaysia
# NASA ATP-program
# National Science Foundation through the Nanoscale Science and Engineering Center
# Swedish Association for Allergology
# National Natural Science Foundation of China excellent university young scholar fund of Guangdong province
# Deutsche Forschungsgesellschaft (DFG) within the Graduiertenkolleg TICMO
#
# Output format: Display a list of the matched organization names followed by the reason for their selection in a json format with the organisation name as key and reason as value.
#
# Sample Input:
# NSF-GFRP
# ACTS national research program from the Netherlands
# Portuguese National Funds (FCT-Fundacao para a Ciencia e a Tecnologia)
# US National Institute of General Medicine
# NSF QIS
# FIST grant of DST
# National Science Foundation under IGERT award
#
# Sample Output:
# {
# 'NSF-GFRP': "contains the string 'nsf'",
# 'NSF QIS': "contains the string 'nsf'",
# 'National Science Foundation under IGERT award': "contains the string 'national science foundation'"
# }
#
# Additional note: You can also filter names of organizations without complete matches of strings 'nsf' or 'national science foundation' string, but make sure to provide a reason for displaying that match. There can be situations where none of the organisations match the criteria, then generate an empty json

# %%
sample_3 = {
"National High Magnetic Field Laboratory through the NSF": "Contains 'NSF' in the name",
"National Science Foundation and Environmental Protection Agency program Networks for Sustainable Material Synthesis and Design": "Contains 'National Science Foundation' in the name",
"NSF at Northwestern University": "Contains 'NSF' in the name",
"U.S.National Science Foundation (NSF)": "Contains both 'National Science Foundation' and 'NSF'",
"National Science Foundation through the Nanoscale Science and Engineering Center": "Contains 'National Science Foundation' in the name",
"National Natural Science Foundation of China excellent university young scholar fund of Guangdong province": "Contains 'National' and 'Science Foundation' in the name, but refers to a Chinese organization, not the U.S. NSF"
}

# %% [markdown]
# Data: data\samples_1\organisation_sample_4.csv
#
# Prompt:
#
# Context: A dataset contains a column named 'Organisation' which contains the organisation names of different funding organisations.
#
# Task: Your task is to display the organisation names that are affiliated to or a part of national science foundation (nsf). You can do this by checking if an organisation name has the complete string of 'national science foundation' or 'nsf' in it. Ignore the case specific string matching.
#
# Data to filter from:
# "Bharat Institute of Technology, Meerut, India"
# Pediatric Brain Injury Research Program
# Tsinghua Outstanding Postdoctoral Fellowship
# ARRS programme
# Australian Government Research Training Scheme Stipend
# TAKE 5 project - Finnish Funding Agency for Technology and Innovation (TEKES)
# Great Basin Paleoindian Research Unit (GBPRU)
# Iranian Nano Initiative
# North American Millers' Association
# RFDP of High Education of China
# European Research Council (ERC Advanced Investigator)
# National Research Council of Science and Technology [Creative Allied Project (CAP)]
# Key Projects of Beijing Science Technology
# Conselho Nacional de Desenvolvimento Cientifico e Tecnologico (National Council for Scientific and Technological Development - CNPq)
# Korea Research Fellowship Program - Ministry of Science and ICT through the National Research Foundation of Korea
# ACS Scholar Award
# SEDF
# Industrial Development Authority of Ireland
# "National Institute of Nutrition and Food Safety, China Centre for Disease Control and Prevention"
# "Carl Tryggers Foundation, Stockholm, Sweden"
# European Social Fund through the ESF Operational Programme for the Balearic Islands
# "Nuclear R&D Program through the Ministry of Science, ICT & Future Planning"
# Wallace H. Coulter Distinguished Faculty Chair funds
# Entertainment Industry Foundation (EIF)
# New Jersey Department of Military and Veterans Affairs
#
# Output format: Display a list of the matched organization names followed by the reason for their selection in a json format with the organisation name as key and reason as value.
#
# Sample Input:
# NSF-GFRP
# ACTS national research program from the Netherlands
# Portuguese National Funds (FCT-Fundacao para a Ciencia e a Tecnologia)
# US National Institute of General Medicine
# NSF QIS
# FIST grant of DST
# National Science Foundation under IGERT award
#
# Sample Output:
# {
# 'NSF-GFRP': "contains the string 'nsf'",
# 'NSF QIS': "contains the string 'nsf'",
# 'National Science Foundation under IGERT award': "contains the string 'national science foundation'"
# }
#
# Additional note: You can also filter names of organizations without complete matches of strings 'nsf' or 'national science foundation' string, but make sure to provide a reason for displaying that match. There can be situations where none of the organisations match the criteria, then generate an empty json

# %%
sample_4 = {}

# %% [markdown]
# Data: data\samples_1\organisation_sample_5.csv
#
# Prompt:
#
# Context: A dataset contains a column named 'Organisation' which contains the organisation names of different funding organisations.
#
# Task: Your task is to display the organisation names that are affiliated to or a part of national science foundation (nsf). You can do this by checking if an organisation name has the complete string of 'national science foundation' or 'nsf' in it. Ignore the case specific string matching.
#
# Data to filter from:
# NSF/SHINE grant
# Key Project of Science and Technology Department of Zhejiang Province
# University of Malaya PPP
# Japan Racing and Livestock Promotion Foundation
# Heinz Endowment
# Major Program of Innovation Research Team of Educational Commission of Guizhou Province of China
# FRQNT Doctoral Scholarship
# Canada Research Chair in Health Services and Systems Research
# "Ministery of Research and Innovation, CNCS-UEFISCDI, within PNCDI III"
# "Ministry of Science and Culture of the State of Lower Saxony, Hannover, Germany"
# Centre National d'Etudes Spatiales in France
# "University of California, San Francisco-Clinical and Translational Science Institute"
# "Ministry of Science and Innovation of Spain, MICINN"
# German Science Foundation (DFG) Emmy Noether program
# Massachusetts General Hospital Fund for Medical Discovery
# EU FET FP7 BIOMICS project
# "Spanish Ministry of Education, Culture and Sport through the National Training Program of University Lecturers (FPU)"
# "The U.S. Environmental Protection Agency, through its Office of Research and Development"
# "Fondo de Investigacion Sanitaria (FIS) of the Instituto de Salud Carlos III, Madrid, Spain"
# "KNAUF GmbH, Branch Spain"
# 10th Five Years Key Programs for Science and Technology Development of China
# PRIN COFIN project
# University Ca' Foscari of Venice
# CONICYT PhD studentship
# Ministerio de Educacioon y Ciencia
#
# Output format: Display a list of the matched organization names followed by the reason for their selection in a json format with the organisation name as key and reason as value.
#
# Sample Input:
# NSF-GFRP
# ACTS national research program from the Netherlands
# Portuguese National Funds (FCT-Fundacao para a Ciencia e a Tecnologia)
# US National Institute of General Medicine
# NSF QIS
# FIST grant of DST
# National Science Foundation under IGERT award
#
# Sample Output:
# {
# 'NSF-GFRP': "contains the string 'nsf'",
# 'NSF QIS': "contains the string 'nsf'",
# 'National Science Foundation under IGERT award': "contains the string 'national science foundation'"
# }
#
# Additional note: You can also filter names of organizations without complete matches of strings 'nsf' or 'national science foundation' string, but make sure to provide a reason for displaying that match. There can be situations where none of the organisations match the criteria, then generate an empty json

# %%
sample_5 = {
"NSF/SHINE grant": "Contains 'NSF' in the name, likely affiliated with the National Science Foundation"
}

# %% [markdown]
# Data: data\samples_1\organisation_sample_6.csv
#
# Prompt:
#
# Context: A dataset contains a column named 'Organisation' which contains the organisation names of different funding organisations.
#
# Task: Your task is to display the organisation names that are affiliated to or a part of national science foundation (nsf). You can do this by checking if an organisation name has the complete string of 'national science foundation' or 'nsf' in it. Ignore the case specific string matching.
#
# Data to filter from:
# "Laboratory for Marine Biology and Biotechnology, Qingdao National Laboratory for Marine Science and Technology"
# GNV
# NSF CCR
# Scientific Research Projects Coordinating Office of Erciyes University (EU-BAP)
# Ministry of Council Resolution
# International Space Weather Initiative Program (ISWI)
# University of Texas at Austin startup funds
# "Dalarna University, Sweden"
# Provincia di Bolzano (Italy)
# Sera Prognostics
# Lawrence National Laboratory Berkeley
# "FAPESP - Fundacao de Amparo a Pesquisa do Estado de Sao Paulo (Sao Paulo, Brazil)"
# Vinci Program (Italian-French University)
# IESL-FORTH
# Site de Recherche Integree sur le Cancer
# National Institutes of Health from the National Science Foundation
# NIHR Applied Programme Grant
# Shanghai Educational Committee Technology Foundation
# Fishery Agency of Japan
# Science Technology and Innovation Commission of Shenzhen
# Key Laboratory Foundation of Shaanxi Engineering and Technique Research Center for Road and Traffic Detection
# U.S. Department of Justice
# National Science Foundation though PENN MRSEC
# Erich and Gertrud Roggenbuck-Stiftung
# National University of Sciences and Technology (NUST) Islamabad
#
# Output format: Display a list of the matched organization names followed by the reason for their selection in a json format with the organisation name as key and reason as value.
#
# Sample Input:
# NSF-GFRP
# ACTS national research program from the Netherlands
# Portuguese National Funds (FCT-Fundacao para a Ciencia e a Tecnologia)
# US National Institute of General Medicine
# NSF QIS
# FIST grant of DST
# National Science Foundation under IGERT award
#
# Sample Output:
# {
# 'NSF-GFRP': "contains the string 'nsf'",
# 'NSF QIS': "contains the string 'nsf'",
# 'National Science Foundation under IGERT award': "contains the string 'national science foundation'"
# }
#
# Additional note: You can also filter names of organizations without complete matches of strings 'nsf' or 'national science foundation' string, but make sure to provide a reason for displaying that match. There can be situations where none of the organisations match the criteria, then generate an empty json

# %%
sample_6 = {
"NSF CCR": "Contains 'NSF' in the name, likely affiliated with the National Science Foundation",
"National Institutes of Health from the National Science Foundation": "Explicitly mentions 'National Science Foundation'",
"National Science Foundation though PENN MRSEC": "Contains 'National Science Foundation' in the name, likely affiliated with the NSF"
}

# %%
import pandas as pd

# Function to convert a dictionary to a DataFrame with a sample column
def dict_to_df(d, sample_name):
    df = pd.DataFrame(list(d.items()), columns=['Organisation', 'Reason'])
    df['Sample'] = sample_name
    return df

# Convert each dictionary to a DataFrame and assign a sample label
df1 = dict_to_df(sample_1, 'sample_1')
df2 = dict_to_df(sample_2, 'sample_2')
df3 = dict_to_df(sample_3, 'sample_3')
df4 = dict_to_df(sample_4, 'sample_4')
df5 = dict_to_df(sample_5, 'sample_5')
df6 = dict_to_df(sample_6, 'sample_6')

# Concatenate all DataFrames into one
combined_df = pd.concat([df1, df2, df3, df4, df5, df6])

# Reset index to ensure it's unique across the combined DataFrame
combined_df.reset_index(drop=True, inplace=True)

# Save the combined DataFrame to a CSV file
combined_df.to_csv('combined_organisations.csv', index=False)

# Optionally, print the combined DataFrame to verify its contents
print(combined_df)
# Out:
#                                          Organisation  \
# 0   NSF Grant from the US National Science Foundation
# 1                                     NSF-ELT program
# 2                                NSF Aeronomy Program
# 3                     National Science Foundation NRT
# 4            National Science Foundation LTER program
# 5           National Science Foundation ADVANCE grant
# 6                                             NSF MWN
# 7       Division of Engineering Education and Centers
# 8   project of national science and technology sup...
# 9   National High Magnetic Field Laboratory throug...
# 10  National Science Foundation and Environmental ...
# 11                     NSF at Northwestern University
# 12              U.S.National Science Foundation (NSF)
# 13  National Science Foundation through the Nanosc...
# 14  National Natural Science Foundation of China e...
# 15                                    NSF/SHINE grant
# ...

# %%
combined_df.head()
# Out:
#                                         Organisation  \
# 0  NSF Grant from the US National Science Foundation
# 1                                    NSF-ELT program
# 2                               NSF Aeronomy Program
# 3                    National Science Foundation NRT
# 4           National Science Foundation LTER program
#
#                                               Reason    Sample
# 0                          contains the string 'nsf'  sample_1
# 1                          contains the string 'nsf'  sample_1
# 2                          contains the string 'nsf'  sample_1
# 3  contains the string 'national science foundation'  sample_1
# 4  contains the string 'national science foundation'  sample_1

# %%
combined_df.head(20)
# Out:
#                                          Organisation  \
# 0   NSF Grant from the US National Science Foundation
# 1                                     NSF-ELT program
# 2                                NSF Aeronomy Program
# 3                     National Science Foundation NRT
# 4            National Science Foundation LTER program
# 5           National Science Foundation ADVANCE grant
# 6                                             NSF MWN
# 7       Division of Engineering Education and Centers
# 8   project of national science and technology sup...
# 9   National High Magnetic Field Laboratory throug...
# 10  National Science Foundation and Environmental ...
# 11                     NSF at Northwestern University
# 12              U.S.National Science Foundation (NSF)
# 13  National Science Foundation through the Nanosc...
# 14  National Natural Science Foundation of China e...
# 15                                    NSF/SHINE grant
# ...

# %%
# Converting organisation names to sets for easy comparison
set_manual = set(df_main['Organisation'])
set_gpt = set(combined_df['Organisation'])

# Calculating True Positives (TP): Names in both manual and gpt
true_positives = set_manual.intersection(set_gpt)

# Calculating False Negatives (FN): Names in manual but not in gpt
false_positives = set_manual.difference(set_gpt)

# Calculating False Positives (FP): Names in gpt but not in manual
false_negatives = set_gpt.difference(set_manual)

# Results
print("True Positives (TP):", true_positives)
print(len(true_positives))
print("False Positives (FP):", false_positives)
print(len(false_positives))
print("False Negatives (FN):", false_negatives)
print(len(false_negatives))
# Out:
# True Positives (TP): {'National High Magnetic Field Laboratory through the NSF', 'National Science Foundation LTER program', 'NSF MWN', 'National Science Foundation NRT', 'NSF CCR', 'NSF-ELT program', 'National Science Foundation and Environmental Protection Agency program Networks for Sustainable Material Synthesis and Design', 'National Institutes of Health from the National Science Foundation', 'National Science Foundation through the Nanoscale Science and Engineering Center', 'NSF/SHINE grant', 'National Science Foundation though PENN MRSEC', 'NSF at Northwestern University', 'U.S.National Science Foundation (NSF)', 'NSF Grant from the US National Science Foundation', 'National Science Foundation ADVANCE grant', 'NSF Aeronomy Program'}
# 16
# False Positives (FP): set()
# 0
# ...
